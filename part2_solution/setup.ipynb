# %%
# !bash build.sh
# Out:
#   adding: elasticsearch-cognito.py (deflated 66%)
# /home/ec2-user/SageMaker/voice-of-customer-integration-handson/part2_solution
#   adding: check_transcribe.py (deflated 56%)
# /home/ec2-user/SageMaker/voice-of-customer-integration-handson/part2_solution
#   adding: elasticsearch-cognito.py (deflated 69%)
# /home/ec2-user/SageMaker/voice-of-customer-integration-handson/part2_solution
#   adding: elasticsearch-6.2.0.dist-info/ (stored 0%)
#   adding: elasticsearch-6.2.0.dist-info/WHEEL (deflated 14%)
#   adding: elasticsearch-6.2.0.dist-info/metadata.json (deflated 61%)
#   adding: elasticsearch-6.2.0.dist-info/top_level.txt (stored 0%)
#   adding: elasticsearch-6.2.0.dist-info/RECORD (deflated 57%)
#   adding: elasticsearch-6.2.0.dist-info/DESCRIPTION.rst (deflated 58%)
#   adding: elasticsearch-6.2.0.dist-info/METADATA (deflated 62%)
#   adding: elasticsearch-6.2.0.dist-info/INSTALLER (stored 0%)
#   adding: certifi/ (stored 0%)
#   adding: certifi/__main__.py (deflated 5%)
# ...

# %%
bucket = 'voice-of-customer-gokazu-20201027'
# ex) voice-of-customer-{name}-{date}

# %%
# !aws s3 mb s3://{bucket}
# Out:
# make_bucket failed: s3://voice-of-customer-gokazu-20201027 An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
# !aws s3 sync . s3://{bucket}/asset --acl public-read
# Out:
# upload failed: .ipynb_checkpoints/setup-checkpoint.ipynb to s3://voice-of-customer-gokazu-20201027/asset/.ipynb_checkpoints/setup-checkpoint.ipynb An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# upload failed: ./build.sh to s3://voice-of-customer-gokazu-20201027/asset/build.sh An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# upload failed: ci/base-pipeline.json to s3://voice-of-customer-gokazu-20201027/asset/ci/base-pipeline.json An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# upload failed: ci/config.yml to s3://voice-of-customer-gokazu-20201027/asset/ci/config.yml An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# upload failed: ./default_dashboards.json to s3://voice-of-customer-gokazu-20201027/asset/default_dashboards.json An error occurred (AccessDenied) when calling the PutObject operation: Access Denied
# ...
